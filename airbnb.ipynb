# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallikavyas/Airbnb-Data-Analysis/blob/main/airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 11.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
from pymongo import MongoClient
client=MongoClient('mongodb+srv://pravallika:motive23@cluster0.tpxro9z.mongodb.net/?retryWrites=true&w=majority')

# %%
db=client['sample_airbnb']
col=db['listingsAndReviews']

# %%
data=[]
for i in col.find( ):
  data.append(i)
print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data[0]
# Out:
# {'_id': '10057447',
#  'listing_url': 'https://www.airbnb.com/rooms/10057447',
#  'name': 'Modern Spacious 1 Bedroom Loft',
#  'summary': 'Prime location, amazing lighting and no annoying neighbours.  Good place to rent if you want a relaxing time in Montreal.',
#  'space': "Lot's of plants and lights.  Really great modern bathroom that you will love showering in :) and a kitchen equipped with everything you need to cook a great meal.  (we live here)",
#  'description': "Prime location, amazing lighting and no annoying neighbours.  Good place to rent if you want a relaxing time in Montreal. Lot's of plants and lights.  Really great modern bathroom that you will love showering in :) and a kitchen equipped with everything you need to cook a great meal.  (we live here)",
#  'neighborhood_overview': '',
#  'notes': '',
#  'transit': '',
#  'access': '',
#  'interaction': '',
#  'house_rules': '',
#  'property_type': 'Apartment',
#  'room_type': 'Entire home/apt',
# ...

# %%
data = []
for i in col.find({},{'_id':1,'name':1,'access':1,'property_type':1,'room_type':1,'bed_type':1,'minimum_nights':1,'maximum_nights':1,'cancellation_policy':1,'accommodates':1,'bedrooms':1,'beds':1,'number_of_reviews':1,'bathrooms':1,'price':1,'security_deposit':1,'cleaning_fee':1,'extra_people':1,'guests_included':1,'review_scores.review_scores_rating':1}):
  data.append(i)
df=pd.DataFrame(data)
df['review_scores'] = df['review_scores'].apply(lambda x: x.get('review_scores_rating',0))
df
# Out:
#            _id                                               name  \
# 0     10057447                     Modern Spacious 1 Bedroom Loft
# 1     10051164                 Catete's Colonial Big Hause Room B
# 2      1003530                New York City - Upper West Side Apt
# 3     10059872                 Soho Cozy, Spacious and Convenient
# 4     10009999                       Horto flat with small garden
# ...        ...                                                ...
# 5550   9907103                   Brand New Luxury Downtown Studio
# 5551   9993190  Just Steps from the Ocean at Premier Platinum ...
# 5552   9987200       The best suite in Copacabana (total privacy)
# 5553   9990304     March Madness Special! Aina Nalu Platinum D107
# 5554   9985696                                    Kadıköy-Altıyol
#
#                                                  access property_type  \
# 0                                                           Apartment
# ...

# %%
df.isnull().sum()
# Out:
# _id                       0
# name                      0
# access                    0
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# price                     0
# extra_people              0
# guests_included           0
# review_scores             0
# security_deposit       2084
# cleaning_fee           1531
# dtype: int64

# %%
df['bedrooms'].fillna(0,inplace=True)
df['beds'].fillna(0,inplace=True)
df['bathrooms'].fillna(0,inplace=True)
df['security_deposit'].fillna('Not Specified',inplace=True)
df['cleaning_fee'].fillna('Not Specified',inplace=True)
df.isnull().sum()
# Out:
# _id                    0
# name                   0
# access                 0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# price                  0
# extra_people           0
# guests_included        0
# review_scores          0
# security_deposit       0
# cleaning_fee           0
# dtype: int64

# %%
df.dtypes
# Out:
# _id                     object
# name                    object
# access                  object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights          object
# maximum_nights          object
# cancellation_policy     object
# accommodates             int64
# bedrooms               float64
# beds                   float64
# number_of_reviews        int64
# bathrooms               object
# price                   object
# extra_people            object
# guests_included         object
# review_scores            int64
# security_deposit        object
# cleaning_fee            object
# dtype: object

# %%
df['_id']=df['_id'].astype(int)

# %%
df.head(5)
# Out:
#         _id                                 name  \
# 0  10057447       Modern Spacious 1 Bedroom Loft
# 1  10051164   Catete's Colonial Big Hause Room B
# 2   1003530  New York City - Upper West Side Apt
# 3  10059872   Soho Cozy, Spacious and Convenient
# 4  10009999         Horto flat with small garden
#
#                                               access property_type  \
# 0                                                        Apartment
# 1  O hóspedes poderão acessar espaços compartilha...         House
# 2                                     New York City!     Apartment
# 3                                                        Apartment
# 4                                                        Apartment
#
#          room_type  bed_type minimum_nights maximum_nights  \
# 0  Entire home/apt  Real Bed              1           1125
# 1     Private room  Real Bed              2           1125
# 2     Private room  Real Bed             12            360
# ...

# %%
df['minimum_nights'] = df['minimum_nights'].astype(int)
df['maximum_nights'] = df['maximum_nights'].astype(int)
df['bedrooms'] = df['bedrooms'].astype(int)
df['beds'] = df['beds'].astype(int)
df['bathrooms'] = df['bathrooms'].astype(str).astype(float)
df['price'] = df['price'].astype(str).astype(float)
df['cleaning_fee'] = df['cleaning_fee'].apply(lambda x: int(float(str(x))) if x != 'Not Specified' else 'Not Specified')
df['security_deposit'] = df['security_deposit'].apply(lambda x: int(float(str(x))) if x != 'Not Specified' else 'Not Specified')
df['extra_people'] = df['extra_people'].astype(str).astype(float).astype(int)
df['guests_included'] = df['guests_included'].astype(str).astype(int)

# %%
df.dtypes
# Out:
# _id                      int64
# name                    object
# access                  object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights           int64
# maximum_nights           int64
# cancellation_policy     object
# accommodates             int64
# bedrooms                 int64
# beds                     int64
# number_of_reviews        int64
# bathrooms              float64
# price                  float64
# extra_people             int64
# guests_included          int64
# review_scores            int64
# security_deposit        object
# cleaning_fee            object
# dtype: object

# %%
host = []
for i in col.find({},{'_id':1,'host':1}):
    host.append(i)
df1=pd.DataFrame(host)

# %%
df1
# Out:
#            _id                                               host
# 0     10057447  {'host_id': '51612949', 'host_url': 'https://w...
# 1     10051164  {'host_id': '51326285', 'host_url': 'https://w...
# 2      1003530  {'host_id': '454250', 'host_url': 'https://www...
# 3     10059872  {'host_id': '51624384', 'host_url': 'https://w...
# 4     10009999  {'host_id': '1282196', 'host_url': 'https://ww...
# ...        ...                                                ...
# 5550   9907103  {'host_id': '35533112', 'host_url': 'https://w...
# 5551   9993190  {'host_id': '51013381', 'host_url': 'https://w...
# 5552   9987200  {'host_id': '51314789', 'host_url': 'https://w...
# 5553   9990304  {'host_id': '51013381', 'host_url': 'https://w...
# 5554   9985696  {'host_id': '51303748', 'host_url': 'https://w...
#
# [5555 rows x 2 columns]

# %%
host_keys=list(df1.iloc[0,1].keys())
host_keys
# Out:
# ['host_id',
#  'host_url',
#  'host_name',
#  'host_location',
#  'host_about',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_is_superhost',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications']

# %%
host_keys.remove('host_about')

# %%
for i in host_keys:
    if i == 'host_response_time':
        df1['host_response_time'] = df1['host'].apply(lambda x:x['host_response_time'] if 'host_response_time' in x else 'Not Specified')
    else:
        df1[i] = df1['host'].apply(lambda x: x[i] if i in x and x[i]!='' else 'Not Specified')
df1.drop(columns=['host'],inplace=True)

# %%
df1
# Out:
#            _id   host_id                                    host_url  \
# 0     10057447  51612949  https://www.airbnb.com/users/show/51612949
# 1     10051164  51326285  https://www.airbnb.com/users/show/51326285
# 2      1003530    454250    https://www.airbnb.com/users/show/454250
# 3     10059872  51624384  https://www.airbnb.com/users/show/51624384
# 4     10009999   1282196   https://www.airbnb.com/users/show/1282196
# ...        ...       ...                                         ...
# 5550   9907103  35533112  https://www.airbnb.com/users/show/35533112
# 5551   9993190  51013381  https://www.airbnb.com/users/show/51013381
# 5552   9987200  51314789  https://www.airbnb.com/users/show/51314789
# 5553   9990304  51013381  https://www.airbnb.com/users/show/51013381
# 5554   9985696  51303748  https://www.airbnb.com/users/show/51303748
#
#            host_name                                    host_location  \
# ...

# %%
df1.drop(columns=['host_url','host_thumbnail_url','host_picture_url'],inplace=True)

# %%
df1.isnull().sum()
# Out:
# _id                          0
# host_id                      0
# host_name                    0
# host_location                0
# host_neighbourhood           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
df1.head(1)
# Out:
#         _id   host_id   host_name             host_location  \
# 0  10057447  51612949  Konstantin  Montreal, Quebec, Canada
#
#   host_neighbourhood  host_is_superhost  host_has_profile_pic  \
# 0           Mile End              False                  True
#
#    host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                   False                    1                          1
#
#                                   host_verifications
# 0  [email, phone, jumio, offline_government_id, s...

# %%
df1.dtypes
# Out:
# _id                          object
# host_id                      object
# host_name                    object
# host_location                object
# host_neighbourhood           object
# host_is_superhost              bool
# host_has_profile_pic           bool
# host_identity_verified         bool
# host_listings_count           int64
# host_total_listings_count     int64
# host_verifications           object
# dtype: object

# %%
df1['host_id']=df1['host_id'].astype(int)
df1['_id']=df1['_id'].astype(int)

# %%
address = []
for i in col.find({},{'_id':1,'address':1}):
    address.append(i)

df2 = pd.DataFrame(address)
address_keys = list(df2.iloc[0,1].keys())

for i in address_keys:
    if i == 'location':
        df2['location_type'] = df2['address'].apply(lambda x: x['location']['type'])
        df2['longitude'] = df2['address'].apply(lambda x: x['location']['coordinates'][0])
        df2['latitude'] = df2['address'].apply(lambda x: x['location']['coordinates'][1])
        df2['is_location_exact'] = df2['address'].apply(lambda x: x['location']['is_location_exact'])
    else:
        df2[i] = df2['address'].apply(lambda x: x[i] if x[i]!='' else 'Not Specified')

df2.drop(columns=['address'], inplace=True)
df2.head()
# Out:
#         _id                                  street  \
# 0  10057447                Montréal, Québec, Canada
# 1  10051164  Rio de Janeiro, Rio de Janeiro, Brazil
# 2   1003530             New York, NY, United States
# 3  10059872  Hong Kong, Hong Kong Island, Hong Kong
# 4  10009999  Rio de Janeiro, Rio de Janeiro, Brazil
#
#                        suburb        government_area          market  \
# 0                    Mile End  Le Plateau-Mont-Royal        Montreal
# 1                      Catete                 Catete  Rio De Janeiro
# 2                   Manhattan        Upper West Side        New York
# 3  Central & Western District      Central & Western       Hong Kong
# 4             Jardim Botânico        Jardim Botânico  Rio De Janeiro
#
#          country country_code location_type   longitude   latitude  \
# 0         Canada           CA         Point  -73.591110  45.518890
# 1         Brazil           BR         Point  -43.180157 -22.926382
# ...

# %%
df2['is_location_exact'] = df2['is_location_exact'].map({False:'No',True:'Yes'})
df2.head()
# Out:
#         _id                                  street  \
# 0  10057447                Montréal, Québec, Canada
# 1  10051164  Rio de Janeiro, Rio de Janeiro, Brazil
# 2   1003530             New York, NY, United States
# 3  10059872  Hong Kong, Hong Kong Island, Hong Kong
# 4  10009999  Rio de Janeiro, Rio de Janeiro, Brazil
#
#                        suburb        government_area          market  \
# 0                    Mile End  Le Plateau-Mont-Royal        Montreal
# 1                      Catete                 Catete  Rio De Janeiro
# 2                   Manhattan        Upper West Side        New York
# 3  Central & Western District      Central & Western       Hong Kong
# 4             Jardim Botânico        Jardim Botânico  Rio De Janeiro
#
#          country country_code location_type   longitude   latitude  \
# 0         Canada           CA         Point  -73.591110  45.518890
# 1         Brazil           BR         Point  -43.180157 -22.926382
# ...

# %%
df2.isnull().sum()
# Out:
# _id                  0
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# location_type        0
# longitude            0
# latitude             0
# is_location_exact    0
# dtype: int64

# %%
df2.dtypes
# Out:
# _id                   object
# street                object
# suburb                object
# government_area       object
# market                object
# country               object
# country_code          object
# location_type         object
# longitude            float64
# latitude             float64
# is_location_exact     object
# dtype: object

# %%
df2['_id']=df2['_id'].astype(int)

# %%
df2.head()
# Out:
#         _id                                  street  \
# 0  10057447                Montréal, Québec, Canada
# 1  10051164  Rio de Janeiro, Rio de Janeiro, Brazil
# 2   1003530             New York, NY, United States
# 3  10059872  Hong Kong, Hong Kong Island, Hong Kong
# 4  10009999  Rio de Janeiro, Rio de Janeiro, Brazil
#
#                        suburb        government_area          market  \
# 0                    Mile End  Le Plateau-Mont-Royal        Montreal
# 1                      Catete                 Catete  Rio De Janeiro
# 2                   Manhattan        Upper West Side        New York
# 3  Central & Western District      Central & Western       Hong Kong
# 4             Jardim Botânico        Jardim Botânico  Rio De Janeiro
#
#          country country_code location_type   longitude   latitude  \
# 0         Canada           CA         Point  -73.591110  45.518890
# 1         Brazil           BR         Point  -43.180157 -22.926382
# ...

# %%
availability = []
for i in col.find({},{'_id':1, 'availability':1}):
    availability.append(i)
df3 = pd.DataFrame(availability)
availability_keys = list(df3.iloc[0,1].keys())
for i in availability_keys:
    df3['availability_30'] = df3['availability'].apply(lambda x: x['availability_30'])
    df3['availability_60'] = df3['availability'].apply(lambda x: x['availability_60'])
    df3['availability_90'] = df3['availability'].apply(lambda x: x['availability_90'])
    df3['availability_365'] = df3['availability'].apply(lambda x: x['availability_365'])

df3.drop(columns=['availability'], inplace=True)
df3.head()
# Out:
#         _id  availability_30  availability_60  availability_90  \
# 0  10057447                0                0                0
# 1  10051164               10               10               21
# 2   1003530                0                0                0
# 3  10059872                0                0                0
# 4  10009999                0                0                0
#
#    availability_365
# 0                 0
# 1               296
# 2                93
# 3                 0
# 4                 0

# %%
df3.isnull().sum()
# Out:
# _id                 0
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
df3.dtypes
# Out:
# _id                 object
# availability_30      int64
# availability_60      int64
# availability_90      int64
# availability_365     int64
# dtype: object

# %%
df3['_id']=df3['_id'].astype(int)

# %%
new_df = pd.merge(df,df1,on='_id')
new_df = pd.merge(new_df,df2,on='_id')
new_df = pd.merge(new_df,df3,on='_id')
# Out:
#         _id                                 name  \
# 0  10057447       Modern Spacious 1 Bedroom Loft
# 1  10051164   Catete's Colonial Big Hause Room B
# 2   1003530  New York City - Upper West Side Apt
# 3  10059872   Soho Cozy, Spacious and Convenient
# 4  10009999         Horto flat with small garden
#
#                                               access property_type  \
# 0                                                        Apartment
# 1  O hóspedes poderão acessar espaços compartilha...         House
# 2                                     New York City!     Apartment
# 3                                                        Apartment
# 4                                                        Apartment
#
#          room_type  bed_type  minimum_nights  maximum_nights  \
# 0  Entire home/apt  Real Bed               1            1125
# 1     Private room  Real Bed               2            1125
# 2     Private room  Real Bed              12             360
# ...

# %%
new_df
# Out:
#            _id                                               name  \
# 0     10057447                     Modern Spacious 1 Bedroom Loft
# 1     10051164                 Catete's Colonial Big Hause Room B
# 2      1003530                New York City - Upper West Side Apt
# 3     10059872                 Soho Cozy, Spacious and Convenient
# 4     10009999                       Horto flat with small garden
# ...        ...                                                ...
# 5550   9907103                   Brand New Luxury Downtown Studio
# 5551   9993190  Just Steps from the Ocean at Premier Platinum ...
# 5552   9987200       The best suite in Copacabana (total privacy)
# 5553   9990304     March Madness Special! Aina Nalu Platinum D107
# 5554   9985696                                    Kadıköy-Altıyol
#
#                                                  access property_type  \
# 0                                                           Apartment
# ...

# %%
new_df.dtypes
# Out:
# _id                            int64
# name                          object
# access                        object
# property_type                 object
# room_type                     object
# bed_type                      object
# minimum_nights                 int64
# maximum_nights                 int64
# cancellation_policy           object
# accommodates                   int64
# bedrooms                       int64
# beds                           int64
# number_of_reviews              int64
# bathrooms                    float64
# price                        float64
# extra_people                   int64
# guests_included                int64
# review_scores                  int64
# security_deposit              object
# cleaning_fee                  object
# host_id                        int64
# host_name                     object
# host_location                 object
# host_neighbourhood            object
# host_is_superhost               bool
# ...

# %%
new_df.head(2)
# Out:
#         _id                                name  \
# 0  10057447      Modern Spacious 1 Bedroom Loft
# 1  10051164  Catete's Colonial Big Hause Room B
#
#                                               access property_type  \
# 0                                                        Apartment
# 1  O hóspedes poderão acessar espaços compartilha...         House
#
#          room_type  bed_type  minimum_nights  maximum_nights  \
# 0  Entire home/apt  Real Bed               1            1125
# 1     Private room  Real Bed               2            1125
#
#            cancellation_policy  accommodates  ...  country  country_code  \
# 0                     flexible             4  ...   Canada            CA
# 1  strict_14_with_grace_period             8  ...   Brazil            BR
#
#    location_type  longitude   latitude  is_location_exact  availability_30  \
# 0          Point -73.591110  45.518890                Yes                0
# ...

# %%
new_df.to_csv('airbnb.csv',index=False)
